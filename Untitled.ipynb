# %%
import matplotlib.pyplot as plt
from tensorflow import keras
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.applications.resnet50 import ResNet50, preprocess_input

# %%
trainDataDir="./Project/archive/Covid19-dataset/train"


trainDataDir = pathlib.Path(trainDataDir)
print(trainDataDir)

testDataDir="./Project/archive/Covid19-dataset/test"


testDataDir = pathlib.Path(testDataDir)
print(testDataDir)
# Out:
# Project/archive/Covid19-dataset/train
# Project/archive/Covid19-dataset/test

# %%
batch_size = 32
img_height = 160
img_width = 160
IMG_SIZE = (img_height, img_width)

trainDataset = tf.keras.preprocessing.image_dataset_from_directory(
  trainDataDir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

validationDataset = tf.keras.preprocessing.image_dataset_from_directory(
  trainDataDir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = validationDataset.class_names
print(class_names)



#val_batches = tf.data.experimental.cardinality(validationDataset)
#test_dataset = validationDataset.take(val_batches // 3)
#validation_dataset = validationDataset.skip(val_batches // 5)

#print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
#print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Found 251 files belonging to 3 classes.
# Using 201 files for training.
# Found 251 files belonging to 3 classes.
# Using 50 files for validation.
# ['Covid', 'Normal', 'Viral Pneumonia']

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

trainDataset = trainDataset.prefetch(buffer_size=AUTOTUNE)
validationDataset = validationDataset.prefetch(buffer_size=AUTOTUNE)
#test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

#class_names = validationDataset.class_names
print(trainDataset)
# Out:
# <PrefetchDataset shapes: ((None, 160, 160, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in trainDataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.Xception(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
#this is feature extraction

image_batch, label_batch = next(iter(trainDataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 5, 5, 2048)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 79, 79, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 79, 79, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 79, 79, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#this is feature extraction
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 2048)

# %%
#this is feature extraction

predLayer = tf.keras.layers.Dense(3,activation='softmax')
prediction_batch = predLayer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 3)

# %%
# Initialize top layer
inputs = tf.keras.Input(shape=(img_height, img_width, 3))
x = data_augmentation(inputs)

norm_layer = keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)
var = mean ** 2
x = norm_layer(x)
norm_layer.set_weights([mean, var])

#x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = predLayer(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 160, 160, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 6147
# ...

# %%
initial_epochs = 20
es = EarlyStopping(patience=5, restore_best_weights=True)

history = model.fit(trainDataset,
                    epochs=initial_epochs,
                    #callbacks=[es],
                    validation_data=validationDataset)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 11s 2s/step - loss: 0.9989 - accuracy: 0.5622 - val_loss: 0.8458 - val_accuracy: 0.6600
# Epoch 2/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.8798 - accuracy: 0.6965 - val_loss: 0.7826 - val_accuracy: 0.7800
# Epoch 3/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.8014 - accuracy: 0.7960 - val_loss: 0.7773 - val_accuracy: 0.8000
# Epoch 4/20
# 7/7 [==============================] - 7s 991ms/step - loss: 0.7727 - accuracy: 0.8358 - val_loss: 0.7544 - val_accuracy: 0.8200
# Epoch 5/20
# 7/7 [==============================] - 7s 983ms/step - loss: 0.7443 - accuracy: 0.8657 - val_loss: 0.7353 - val_accuracy: 0.8400
# Epoch 6/20
# 7/7 [==============================] - 7s 946ms/step - loss: 0.7397 - accuracy: 0.8458 - val_loss: 0.7494 - val_accuracy: 0.8000
# Epoch 7/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.7137 - accuracy: 0.8756 - val_loss: 0.7869 - val_accuracy: 0.7600
# ...

# %%
predict(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ff49d408a334> in <module>
# ----> 1 predict(history)
#
# NameError: name 'predict' is not defined

# %%
#loss, accuracy = model.evaluate(test_dataset)
#print('Test accuracy :', accuracy)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([min(plt.ylim()),max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
base_model.trainable = True
print("Number of layers in the base model: ", len(base_model.layers))
# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable =  False
# Out:
# Number of layers in the base model:  132

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 160, 160, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 6147
# ...

# %%
initial_epochs = 15

history_new = model.fit(trainDataset,
                    epochs=initial_epochs,
                    #callbacks=[es],
                    validation_data=validationDataset)
# Out:
# Epoch 1/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6767 - accuracy: 0.8905 - val_loss: 0.7238 - val_accuracy: 0.8000
# Epoch 2/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6593 - accuracy: 0.8905 - val_loss: 0.7634 - val_accuracy: 0.7800
# Epoch 3/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6001 - accuracy: 0.9602 - val_loss: 0.6524 - val_accuracy: 0.9000
# Epoch 4/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6393 - accuracy: 0.9104 - val_loss: 0.7607 - val_accuracy: 0.8000
# Epoch 5/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6201 - accuracy: 0.9204 - val_loss: 0.6655 - val_accuracy: 0.9000
# Epoch 6/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.5799 - accuracy: 0.9751 - val_loss: 0.6550 - val_accuracy: 0.9000
# Epoch 7/15
# 7/7 [==============================] - 10s 1s/step - loss: 0.6013 - accuracy: 0.9502 - val_loss: 0.7517 - val_accuracy: 0.8200
# ...

# %%
def plot_metrics(history):
  metrics = ['loss', 'auc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color='blue', label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color="blue", linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-c024a8f300f3> in <module>
# ----> 1 plot_metrics(history_new)
#
# <ipython-input-23-4584af9cf4d5> in plot_metrics(history)
#       4     name = metric.replace("_"," ").capitalize()
#       5     plt.subplot(2,2,n+1)
# ----> 6     plt.plot(history.epoch, history.history[metric], color='blue', label='Train')
#       7     plt.plot(history.epoch, history.history['val_'+metric],
#       8              color="blue", linestyle="--", label='Val')
#
# KeyError: 'auc'

# %%
acc += history_new.history['accuracy']
val_acc += history_new.history['val_accuracy']

loss += history_new.history['loss']
val_loss += history_new.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 2.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import os
real = []
pred_arr = [] 
Cmatrix = [[0 for i in range(len(class_names))]for j in range(len(class_names))]
def predict():
    test_dir = "./Project/archive/Covid19-dataset/test"
    #test_dir = pathlib.Path(test_dir)Viral Pneumonia/0101.jpeg
    class_names = ['Covid', 'Normal', 'Viral Pneumonia']
    #class_names.remove('Normal')
    
   
    book = {"Covid":1, "Normal":-1}
    
    for j in range(len(class_names)):
        test_dir = "./Project/archive/Covid19-dataset/test"
        path = test_dir + '/'+class_names[j]+'/'
        print("Actual Label",class_names[j])
        for i in os.listdir(path):
            test_dir = pathlib.Path(path+str(i))

            img = keras.preprocessing.image.load_img(
            test_dir, target_size=(img_height, img_width))
            img_array = keras.preprocessing.image.img_to_array(img)
            img_array = tf.expand_dims(img_array, 0) # Create a batch

            predictions = model.predict(img_array)
            score = tf.nn.softmax(predictions[0])
            idx = np.argmax(score)
            
            pred = class_names[idx]
            print(pred,class_names[j])
            
            pred_arr.append(book.get(pred))
            real.append(book.get(class_names[j]))
            if pred == class_names[j]:
                Cmatrix[j][j]+=1

            else:
                index = class_names.index(pred)
                Cmatrix[j][index]+=1

    print(Cmatrix)

predict()
# Out:
# Actual Label Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Normal Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Normal Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Covid Covid
# Actual Label Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Viral Pneumonia Normal
# Normal Normal
# Normal Normal
# Viral Pneumonia Normal
# Viral Pneumonia Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Normal Normal
# Viral Pneumonia Normal
# Normal Normal
# Viral Pneumonia Normal
# Normal Normal
# Normal Normal
# Actual Label Viral Pneumonia
# Viral Pneumonia Viral Pneumonia
# Viral Pneumonia Viral Pneumonia
# Viral Pneumonia Viral Pneumonia
# Viral Pneumonia Viral Pneumonia
# Viral Pneumonia Viral Pneumonia
# ...

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
conLabels = class_names
#x = confusion_matrix(realOutput, output,conLabels)
#print(x)

df_cm = pd.DataFrame(Cmatrix, conLabels, conLabels)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

y_true = np.array(real)
y_score = np.array(pred_arr)
# Compute fpr, tpr, thresholds and roc auc
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(y_true, y_score)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 2.0])
plt.ylim([0.0, 1.5])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
